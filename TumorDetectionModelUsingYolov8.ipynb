# %% [markdown]
# <a href="https://colab.research.google.com/github/RReed637/Brain-Tumor-Detection/blob/main/TumorDetectionModelUsingYolov8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install keras-cv
# !pip install ultralytics
# !pip install segmentation_models
# !pip install cv2
# !pip install torch
# Out:
# Collecting keras-cv
#   Downloading keras_cv-0.8.2-py3-none-any.whl (613 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 613.1/613.1 kB 12.2 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras-cv) (23.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras-cv) (1.4.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from keras-cv) (2023.12.25)
# Requirement already satisfied: tensorflow-datasets in /usr/local/lib/python3.10/dist-packages (from keras-cv) (4.9.4)
# Collecting keras-core (from keras-cv)
#   Downloading keras_core-0.1.7-py3-none-any.whl (950 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 950.8/950.8 kB 61.6 MB/s eta 0:00:00
# Requirement already satisfied: kagglehub in /usr/local/lib/python3.10/dist-packages (from keras-cv) (0.1.9)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kagglehub->keras-cv) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kagglehub->keras-cv) (4.66.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras-core->keras-cv) (1.25.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras-core->keras-cv) (13.7.0)
# Collecting namex (from keras-core->keras-cv)
#   Downloading namex-0.0.7-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-core->keras-cv) (3.9.0)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.10/dist-packages (from keras-core->keras-cv) (0.1.8)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (8.1.7)
# Requirement already satisfied: etils[enp,epath,etree]>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (1.7.0)
# Requirement already satisfied: promise in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (2.3)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (3.20.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (5.9.5)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (1.14.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (2.4.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (0.10.2)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (1.14.1)
# Requirement already satisfied: array-record>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (0.5.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from etils[enp,epath,etree]>=0.9.0->tensorflow-datasets->keras-cv) (2023.6.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.10/dist-packages (from etils[enp,epath,etree]>=0.9.0->tensorflow-datasets->keras-cv) (6.1.1)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.10/dist-packages (from etils[enp,epath,etree]>=0.9.0->tensorflow-datasets->keras-cv) (4.9.0)
# Requirement already satisfied: zipp in /usr/local/lib/python3.10/dist-packages (from etils[enp,epath,etree]>=0.9.0->tensorflow-datasets->keras-cv) (3.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub->keras-cv) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub->keras-cv) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub->keras-cv) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub->keras-cv) (2024.2.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from promise->tensorflow-datasets->keras-cv) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras-core->keras-cv) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras-core->keras-cv) (2.16.1)
# Requirement already satisfied: googleapis-common-protos<2,>=1.52.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-metadata->tensorflow-datasets->keras-cv) (1.62.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras-core->keras-cv) (0.1.2)
# Installing collected packages: namex, keras-core, keras-cv
# Successfully installed keras-core-0.1.7 keras-cv-0.8.2 namex-0.0.7
# Collecting ultralytics
#   Downloading ultralytics-8.1.19-py3-none-any.whl (716 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 716.2/716.2 kB 14.3 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (3.7.1)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.8.0.76)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.11.4)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.1.0+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.16.0+cu121)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.66.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.0.0)
# Collecting thop>=0.1.1 (from ultralytics)
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.5.3)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2023.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2024.2.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (4.9.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Installing collected packages: thop, ultralytics
# Successfully installed thop-0.1.1.post2209072238 ultralytics-8.1.19
# Collecting segmentation_models
#   Downloading segmentation_models-1.0.1-py3-none-any.whl (33 kB)
# Collecting keras-applications<=1.0.8,>=1.0.7 (from segmentation_models)
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 3.6 MB/s eta 0:00:00
# Collecting image-classifiers==1.0.0 (from segmentation_models)
#   Downloading image_classifiers-1.0.0-py3-none-any.whl (19 kB)
# Collecting efficientnet==1.0.0 (from segmentation_models)
#   Downloading efficientnet-1.0.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from efficientnet==1.0.0->segmentation_models) (0.19.3)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation_models) (1.25.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation_models) (3.9.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (1.11.4)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (3.2.1)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (9.4.0)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (2.31.6)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (2024.2.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (23.2)
# Installing collected packages: keras-applications, image-classifiers, efficientnet, segmentation_models
# Successfully installed efficientnet-1.0.0 image-classifiers-1.0.0 keras-applications-1.0.8 segmentation_models-1.0.1
# ERROR: Could not find a version that satisfies the requirement cv2 (from versions: none)
# ERROR: No matching distribution found for cv2
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.1.0+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch) (4.9.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)

# %%
import os
import pickle
import tensorflow as tf
from ultralytics import YOLO
os.environ["KERAS_BACKEND"] = "jax"

from keras_cv.src import bounding_box
from keras_cv.src import layers
import keras_cv
from keras.optimizers import AdamW
from tensorflow.keras.models import load_model
from tensorflow import keras
import tensorflow_datasets as tfds
import tensorflow as tf
import numpy as np
from tqdm import tqdm
import cv2


import pandas as pd
import os

gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)


BATCH_SIZE = 15
GLOBAL_CLIPNORM = 10

AUTO = tf.data.AUTOTUNE
# Out:
# Wed Feb 28 16:19:47 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0              49W / 400W |   8709MiB / 40960MiB |      0%      Default |
# |                                         |                      |             Disabled |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# ### **ONLY RUN THE FOLLOWING TWO CELLS IF YOU NEED TO RECREATE THE PICKLE FILES AS THIS IS TIME INTENSIVE!!!**

# %%
'''Converts given text files to lists'''
def list_annotation(image_path, text_path):
  img = cv2.imread(image_path)
  width = int(img.shape[0])
  height = int(img.shape[1])

  file_label = open(text_path, "r")
  lines = file_label.read().split('\n')


  boxes = []
  classes = []

  if lines[0] == '':
    return image_path, classes, boxes

  else:
    for i in range(0, int(len(lines))):
      objbud = lines[i].split(' ')
      fclass = int(objbud[0])

      x1 = float(objbud[1])
      y1 = float(objbud[2])
      w1 = float(objbud[3])
      h1 = float(objbud[4])

      xmin = int((x1*width)-(w1*width)/2.0)
      ymin = int((y1*height)-(h1*height)/2.0)
      xmax = int((x1*width)+(w1*width)/2.0)
      ymax = int((y1*height)+(h1*height)/2.0)

      boxes.append([xmin, ymin, xmax, ymax])
      classes.append(fclass)

  return image_path, classes, boxes
# Function creating list of file paths
def paths_list(path):
  complete_path = []
  images = sorted(os.listdir(path))

  for i in images:
    complete_path.append(os.path.join(path, i))

  return complete_path

classids = ['Label0', 'Label1', 'Label2']

mapping = dict(zip(range(len(classids)), classids))

mapping

def making_files(img_files_paths, annot_files_paths):
  image_files = paths_list(img_files_paths)
  annot_files = paths_list(annot_files_paths)

  image_path = []
  bbox = []
  classes = []

  for i in range(0,len(image_files)):
    image_path_, classes_, bbox_ = list_annotation(
        image_files[i],
        annot_files[i]
        )
    image_path.append(image_path_)
    bbox.append(bbox_)
    classes.append(classes_)

  image_path = tf.ragged.constant(image_path)
  bbox = tf.ragged.constant(bbox)
  classes = tf.ragged.constant(classes)

  return image_path, classes, bbox

# %%
# Function application

# Check if the pickle files already exist
training_pickle_path = '/content/drive/MyDrive/Brain-Tumor-Detection/data/training_data.pkl'
valid_pickle_path = '/content/drive/MyDrive/Brain-Tumor-Detection/data/valid_data.pkl'
testing_pickle_path = '/content/drive/MyDrive/Brain-Tumor-Detection/data/Testing_data.pkl'

if not (os.path.exists(training_pickle_path) and os.path.exists(valid_pickle_path) and os.path.exists(testing_pickle_path)):
    # If any of the pickle files do not exist, execute the code to create them
    training_image_paths, training_classes, training_bboxes = making_files(
        '/content/drive/MyDrive/Colab Notebooks/Brain Tumor Detection/train/images',
        '/content/drive/MyDrive/Colab Notebooks/Brain Tumor Detection/train/labels'
    )

    with open(training_pickle_path, 'wb') as f:
        pickle.dump([training_image_paths, training_classes, training_bboxes], f)

    valid_image_paths, valid_classes, valid_bboxes = making_files(
        '/content/drive/MyDrive/Colab Notebooks/Brain Tumor Detection/valid/images',
        '/content/drive/MyDrive/Colab Notebooks/Brain Tumor Detection/valid/labels'
    )

    with open(valid_pickle_path, 'wb') as f:
        pickle.dump([valid_image_paths, valid_classes, valid_bboxes], f)

    testing_image_paths, testing_classes, testing_bboxes = making_files(
        '/content/drive/MyDrive/Colab Notebooks/Brain Tumor Detection/test/images',
        '/content/drive/MyDrive/Colab Notebooks/Brain Tumor Detection/test/labels'
    )
    with open(testing_pickle_path, 'wb') as f:
      pickle.dump([testing_image_paths, testing_classes, testing_bboxes], f)
else:
  print("Pickle files already exist. Skipping the process.")

# %%
def image_preprocessing(image_path):
  image = tf.io.read_file(image_path)
  image = tf.image.decode_jpeg(image, channels=3)
  image = tf.cast(image, tf.float32)
  return image

sizing = keras_cv.layers.JitteredResize(
    target_size = (640, 640),
    scale_factor=(0.8, 1.25),
    bounding_box_format="xyxy")

def load_pickle(file_path):
    with open(file_path, 'rb') as f:
        data = pickle.load(f)
    return data


def load_data(image_path,classes,bbox):
        # Preprocess the image data (assuming image_preprocessing is defined somewhere)
        preprocessed_image = image_preprocessing(image_path)

        # Create bounding box dictionary
        bounding_box = {
            "classes": tf.cast(classes, dtype=tf.float32),
            "boxes": bbox
        }

        # Combine image data and bounding box metadata


        return {"images" : preprocessed_image, "bounding_boxes": bounding_box}

# %%
def dict_to_tuple(inputs):
  return inputs["images"], inputs["bounding_boxes"]

# %%
# Model Training
def train_model(model, train_dataset, valid_dataset, epochs):
    model.compile(optimizer=AdamW(learning_rate=0.0001, weight_decay=0.004, global_clipnorm=GLOBAL_CLIPNORM),
                  classification_loss='binary_crossentropy', box_loss='ciou')
    history = model.fit(train_dataset, validation_data=valid_dataset, epochs=epochs)
    return history

# %%
#Model Loading and Saving
def save_model(model, file_path):
    keras.models.save_model(model, file_path)# Load a model


def load_saved_model(file_path):
    return keras.models.load_model(file_path)

# %%
def inspect_pickle_file(file_path):
    with open(file_path, 'rb') as f:
        data = pickle.load(f)

    print("Data loaded from pickle file:")
    print(data)

# Provide the file path of the pickle file you want to inspect
pickle_file_path = '/content/drive/MyDrive/Brain-Tumor-Detection/data/training_data.pkl'
inspect_pickle_file(pickle_file_path)
# Out:
# Data loaded from pickle file:
# [<tf.Tensor: shape=(6930,), dtype=string, numpy=
# array([b'/content/drive/MyDrive/Colab Notebooks/Brain Tumor Detection/train/images/volume_100_slice_100_jpg.rf.ac33e0ac3a1eebeb5e262e8a6f7de5d9.jpg', b'/content/drive/MyDrive/Colab Notebooks/Brain Tumor Detection/train/images/volume_100_slice_101_jpg.rf.1984ae9f91c255104509b3da84cf1be6.jpg',
#        b'/content/drive/MyDrive/Colab Notebooks/Brain Tumor Detection/train/images/volume_100_slice_107_jpg.rf.db31be1f34abd48ca231dc24f59bd81c.jpg', ..., b'/content/drive/MyDrive/Colab Notebooks/Brain Tumor Detection/train/images/volume_9_slice_89_jpg.rf.9ab5b4f5c8635014475feaec7b805cc9.jpg',
#        b'/content/drive/MyDrive/Colab Notebooks/Brain Tumor Detection/train/images/volume_9_slice_91_jpg.rf.615b98cc69d379faff2fed903e6882f9.jpg', b'/content/drive/MyDrive/Colab Notebooks/Brain Tumor Detection/train/images/volume_9_slice_99_jpg.rf.14ac88b25a6ec0bc5dfd604483086f68.jpg'], dtype=object)>, <tf.RaggedTensor [[1], [1], [1], ..., [0, 1, 2], [0, 1, 2], [0, 1, 2]]>, <tf.RaggedTensor [[[55, 9, 107, 57]], [[56, 9, 107, 57]], [[70, 11, 101, 45]], ..., [[30, 7, 100, 55],
#                                                                     [36, 3, 117, 57],
#                                                                     [33, 5, 104, 51]], [[30, 4, 104, 51],
#                                                                                         [36, 3, 127, 56],
#                                                                                         [34, 5, 105, 53]], [[31, 7, 95, 60],
#                                                                                                             [37, 2, 131, 67],
#                                                                                                             [35, 11, 108, 55]]]>]

# %%
strat = tf.distribute.MirroredStrategy()



# Main Function
if __name__ == "__main__":
    # Load data
    training_data = load_pickle('/content/drive/MyDrive/Brain-Tumor-Detection/data/training_data.pkl')
    valid_data = load_pickle('/content/drive/MyDrive/Brain-Tumor-Detection/data/valid_data.pkl')
    testing_data = load_pickle('/content/drive/MyDrive/Brain-Tumor-Detection/data/Testing_data.pkl')

    training_image_paths, training_classes, training_bboxes = training_data
    valid_image_paths, valid_classes, valid_bboxes = valid_data
    testing_image_paths, testing_classes, testing_bboxes = testing_data
    # Create datasets
    train_loader = tf.data.Dataset.from_tensor_slices((training_image_paths, training_classes, training_bboxes))
    train_dataset = (train_loader.map(load_data, num_parallel_calls=AUTO)
                    .shuffle(BATCH_SIZE*10)
                    .ragged_batch(BATCH_SIZE, drop_remainder=True)
                    .map(sizing, num_parallel_calls=AUTO)
                    .map(dict_to_tuple, num_parallel_calls=AUTO)
                    .prefetch(AUTO))

    valid_loader = tf.data.Dataset.from_tensor_slices((valid_image_paths, valid_classes, valid_bboxes))
    valid_dataset = (valid_loader.map(load_data, num_parallel_calls=AUTO)
                    .ragged_batch(BATCH_SIZE, drop_remainder=True)
                    .map(sizing, num_parallel_calls=AUTO)
                    .map(dict_to_tuple, num_parallel_calls=AUTO)
                    .prefetch(AUTO))

    testing_loader = tf.data.Dataset.from_tensor_slices((testing_image_paths, testing_classes, testing_bboxes))
    testing_dataset = (testing_loader.map(load_data, num_parallel_calls=AUTO)
                    .ragged_batch(BATCH_SIZE, drop_remainder=True)
                    .map(sizing, num_parallel_calls=AUTO)
                    .map(dict_to_tuple, num_parallel_calls=AUTO)
                    .prefetch(AUTO))


    # Model Training
    with strat.scope():
        backbone = keras_cv.models.YOLOV8Backbone.from_preset("yolo_v8_xs_backbone_coco")
        YOLOV8 = keras_cv.models.YOLOV8Detector(num_classes=len(mapping), bounding_box_format="xyxy", backbone=backbone, fpn_depth=1)
    hist = train_model(YOLOV8, train_dataset, valid_dataset, 120)
    # Save Model
    save_model(YOLOV8, '/content/drive/MyDrive/Brain-Tumor-Detection/models/TumorDetectionmodel.keras')

#plot loss
# Out:
# Epoch 1/120
# 462/462 [==============================] - 94s 110ms/step - loss: 756.3102 - box_loss: 3.2720 - class_loss: 753.0383 - val_loss: 369.1232 - val_box_loss: 2.8836 - val_class_loss: 366.2396
# Epoch 2/120
# 462/462 [==============================] - 48s 104ms/step - loss: 194.9487 - box_loss: 2.7066 - class_loss: 192.2422 - val_loss: 152.4620 - val_box_loss: 2.7714 - val_class_loss: 149.6905
# Epoch 3/120
# 462/462 [==============================] - 48s 103ms/step - loss: 66.9600 - box_loss: 2.6047 - class_loss: 64.3554 - val_loss: 34.2431 - val_box_loss: 2.5985 - val_class_loss: 31.6446
# Epoch 4/120
# 462/462 [==============================] - 48s 103ms/step - loss: 24.2187 - box_loss: 2.5639 - class_loss: 21.6548 - val_loss: 12.9635 - val_box_loss: 2.5332 - val_class_loss: 10.4303
# Epoch 5/120
# 462/462 [==============================] - 48s 103ms/step - loss: 13.6507 - box_loss: 2.5082 - class_loss: 11.1424 - val_loss: 7.3369 - val_box_loss: 2.5466 - val_class_loss: 4.7903
# Epoch 6/120
# 462/462 [==============================] - 48s 103ms/step - loss: 12.3379 - box_loss: 2.5026 - class_loss: 9.8353 - val_loss: 5.3419 - val_box_loss: 2.5503 - val_class_loss: 2.7915
# Epoch 7/120
# 462/462 [==============================] - 48s 103ms/step - loss: 7.3681 - box_loss: 2.5006 - class_loss: 4.8675 - val_loss: 15.4099 - val_box_loss: 2.4587 - val_class_loss: 12.9512
# Epoch 8/120
# 462/462 [==============================] - 48s 104ms/step - loss: 7.2106 - box_loss: 2.4684 - class_loss: 4.7422 - val_loss: 5.3200 - val_box_loss: 2.4578 - val_class_loss: 2.8622
# Epoch 9/120
# 462/462 [==============================] - 48s 103ms/step - loss: 7.4705 - box_loss: 2.4732 - class_loss: 4.9973 - val_loss: 6.3241 - val_box_loss: 2.4549 - val_class_loss: 3.8693
# Epoch 10/120
# 462/462 [==============================] - 48s 103ms/step - loss: 5.3552 - box_loss: 2.4423 - class_loss: 2.9129 - val_loss: 3.6104 - val_box_loss: 2.4127 - val_class_loss: 1.1978
# Epoch 11/120
# 462/462 [==============================] - 48s 103ms/step - loss: 6.9964 - box_loss: 2.4219 - class_loss: 4.5745 - val_loss: 5.5004 - val_box_loss: 2.4160 - val_class_loss: 3.0844
# Epoch 12/120
# 462/462 [==============================] - 48s 103ms/step - loss: 5.3087 - box_loss: 2.4212 - class_loss: 2.8875 - val_loss: 3.7991 - val_box_loss: 2.4620 - val_class_loss: 1.3370
# Epoch 13/120
# 462/462 [==============================] - 48s 103ms/step - loss: 4.8829 - box_loss: 2.4121 - class_loss: 2.4709 - val_loss: 3.9320 - val_box_loss: 2.4205 - val_class_loss: 1.5115
# Epoch 14/120
# 462/462 [==============================] - 48s 103ms/step - loss: 5.7162 - box_loss: 2.4054 - class_loss: 3.3108 - val_loss: 4.6490 - val_box_loss: 2.4014 - val_class_loss: 2.2476
# Epoch 15/120
# 462/462 [==============================] - 48s 103ms/step - loss: 6.5953 - box_loss: 2.3837 - class_loss: 4.2115 - val_loss: 3.7591 - val_box_loss: 2.4377 - val_class_loss: 1.3214
# Epoch 16/120
# 462/462 [==============================] - 48s 103ms/step - loss: 4.5755 - box_loss: 2.3844 - class_loss: 2.1912 - val_loss: 3.4769 - val_box_loss: 2.3906 - val_class_loss: 1.0863
# Epoch 17/120
# 462/462 [==============================] - 48s 103ms/step - loss: 4.4427 - box_loss: 2.3543 - class_loss: 2.0883 - val_loss: 3.5558 - val_box_loss: 2.4473 - val_class_loss: 1.1085
# Epoch 18/120
# 462/462 [==============================] - 48s 103ms/step - loss: 4.3361 - box_loss: 2.3565 - class_loss: 1.9796 - val_loss: 3.4150 - val_box_loss: 2.3554 - val_class_loss: 1.0597
# Epoch 19/120
# 462/462 [==============================] - 48s 103ms/step - loss: 4.1705 - box_loss: 2.3385 - class_loss: 1.8320 - val_loss: 3.5449 - val_box_loss: 2.4341 - val_class_loss: 1.1108
# Epoch 20/120
# 462/462 [==============================] - 48s 103ms/step - loss: 4.0919 - box_loss: 2.3269 - class_loss: 1.7650 - val_loss: 3.9057 - val_box_loss: 2.4202 - val_class_loss: 1.4855
# Epoch 21/120
# 462/462 [==============================] - 48s 103ms/step - loss: 4.1673 - box_loss: 2.3196 - class_loss: 1.8477 - val_loss: 3.6517 - val_box_loss: 2.4117 - val_class_loss: 1.2400
# Epoch 22/120
# 462/462 [==============================] - 48s 103ms/step - loss: 4.0237 - box_loss: 2.3004 - class_loss: 1.7234 - val_loss: 3.8459 - val_box_loss: 2.4536 - val_class_loss: 1.3922
# Epoch 23/120
# 462/462 [==============================] - 48s 103ms/step - loss: 3.9757 - box_loss: 2.2753 - class_loss: 1.7004 - val_loss: 3.5731 - val_box_loss: 2.4128 - val_class_loss: 1.1603
# Epoch 24/120
# 462/462 [==============================] - 48s 103ms/step - loss: 3.6574 - box_loss: 2.2676 - class_loss: 1.3898 - val_loss: 3.7836 - val_box_loss: 2.4726 - val_class_loss: 1.3110
# Epoch 25/120
# 462/462 [==============================] - 48s 103ms/step - loss: 3.1340 - box_loss: 2.2488 - class_loss: 0.8853 - val_loss: 3.4388 - val_box_loss: 2.5103 - val_class_loss: 0.9285
# Epoch 26/120
# 462/462 [==============================] - 48s 103ms/step - loss: 3.1124 - box_loss: 2.2406 - class_loss: 0.8717 - val_loss: 3.3863 - val_box_loss: 2.4648 - val_class_loss: 0.9215
# Epoch 27/120
# 462/462 [==============================] - 48s 103ms/step - loss: 3.0793 - box_loss: 2.2208 - class_loss: 0.8585 - val_loss: 3.3909 - val_box_loss: 2.4830 - val_class_loss: 0.9078
# Epoch 28/120
# 462/462 [==============================] - 48s 103ms/step - loss: 3.0492 - box_loss: 2.2021 - class_loss: 0.8471 - val_loss: 3.3514 - val_box_loss: 2.4530 - val_class_loss: 0.8984
# Epoch 29/120
# 462/462 [==============================] - 48s 103ms/step - loss: 3.0347 - box_loss: 2.1948 - class_loss: 0.8400 - val_loss: 3.3866 - val_box_loss: 2.4656 - val_class_loss: 0.9209
# Epoch 30/120
# 462/462 [==============================] - 48s 103ms/step - loss: 2.9981 - box_loss: 2.1721 - class_loss: 0.8260 - val_loss: 3.3480 - val_box_loss: 2.4574 - val_class_loss: 0.8906
# Epoch 31/120
# 462/462 [==============================] - 48s 103ms/step - loss: 2.9760 - box_loss: 2.1570 - class_loss: 0.8190 - val_loss: 3.3775 - val_box_loss: 2.4583 - val_class_loss: 0.9192
# Epoch 32/120
# 462/462 [==============================] - 48s 103ms/step - loss: 2.9601 - box_loss: 2.1494 - class_loss: 0.8107 - val_loss: 3.3934 - val_box_loss: 2.4934 - val_class_loss: 0.9000
# Epoch 33/120
# 462/462 [==============================] - 48s 102ms/step - loss: 2.9343 - box_loss: 2.1300 - class_loss: 0.8042 - val_loss: 3.4223 - val_box_loss: 2.5231 - val_class_loss: 0.8992
# Epoch 34/120
# 462/462 [==============================] - 48s 102ms/step - loss: 2.8999 - box_loss: 2.1076 - class_loss: 0.7923 - val_loss: 3.4438 - val_box_loss: 2.5149 - val_class_loss: 0.9289
# Epoch 35/120
# 462/462 [==============================] - 48s 103ms/step - loss: 2.8737 - box_loss: 2.0922 - class_loss: 0.7816 - val_loss: 3.3996 - val_box_loss: 2.5107 - val_class_loss: 0.8889
# Epoch 36/120
# 462/462 [==============================] - 48s 103ms/step - loss: 2.8510 - box_loss: 2.0761 - class_loss: 0.7749 - val_loss: 3.4748 - val_box_loss: 2.5652 - val_class_loss: 0.9097
# Epoch 37/120
# 462/462 [==============================] - 48s 103ms/step - loss: 2.8267 - box_loss: 2.0617 - class_loss: 0.7650 - val_loss: 3.4546 - val_box_loss: 2.5478 - val_class_loss: 0.9069
# Epoch 38/120
# 462/462 [==============================] - 48s 103ms/step - loss: 2.7873 - box_loss: 2.0372 - class_loss: 0.7500 - val_loss: 3.4747 - val_box_loss: 2.5679 - val_class_loss: 0.9068
# Epoch 39/120
# 462/462 [==============================] - 48s 103ms/step - loss: 2.7823 - box_loss: 2.0360 - class_loss: 0.7463 - val_loss: 3.4421 - val_box_loss: 2.5482 - val_class_loss: 0.8939
# Epoch 40/120
# 462/462 [==============================] - 48s 103ms/step - loss: 2.7542 - box_loss: 2.0173 - class_loss: 0.7369 - val_loss: 3.4465 - val_box_loss: 2.5259 - val_class_loss: 0.9206
# Epoch 41/120
# 462/462 [==============================] - 48s 103ms/step - loss: 2.7254 - box_loss: 1.9995 - class_loss: 0.7259 - val_loss: 3.5235 - val_box_loss: 2.5974 - val_class_loss: 0.9261
# Epoch 42/120
# 462/462 [==============================] - 48s 103ms/step - loss: 2.7087 - box_loss: 1.9891 - class_loss: 0.7196 - val_loss: 3.4612 - val_box_loss: 2.5422 - val_class_loss: 0.9189
# Epoch 43/120
# 462/462 [==============================] - 48s 103ms/step - loss: 2.6795 - box_loss: 1.9699 - class_loss: 0.7095 - val_loss: 3.5098 - val_box_loss: 2.5950 - val_class_loss: 0.9148
# Epoch 44/120
# 462/462 [==============================] - 48s 103ms/step - loss: 2.6585 - box_loss: 1.9544 - class_loss: 0.7041 - val_loss: 3.5174 - val_box_loss: 2.6111 - val_class_loss: 0.9063
# Epoch 45/120
# 462/462 [==============================] - 48s 103ms/step - loss: 2.6352 - box_loss: 1.9426 - class_loss: 0.6927 - val_loss: 3.5986 - val_box_loss: 2.6522 - val_class_loss: 0.9465
# Epoch 46/120
# 462/462 [==============================] - 48s 103ms/step - loss: 2.6145 - box_loss: 1.9279 - class_loss: 0.6866 - val_loss: 3.4768 - val_box_loss: 2.5770 - val_class_loss: 0.8998
# Epoch 47/120
# 462/462 [==============================] - 48s 103ms/step - loss: 2.5936 - box_loss: 1.9133 - class_loss: 0.6803 - val_loss: 3.4707 - val_box_loss: 2.5736 - val_class_loss: 0.8970
# Epoch 48/120
# 462/462 [==============================] - 48s 103ms/step - loss: 2.5604 - box_loss: 1.8921 - class_loss: 0.6683 - val_loss: 3.4759 - val_box_loss: 2.5768 - val_class_loss: 0.8991
# Epoch 49/120
# 462/462 [==============================] - 48s 103ms/step - loss: 2.5506 - box_loss: 1.8883 - class_loss: 0.6623 - val_loss: 3.6042 - val_box_loss: 2.6569 - val_class_loss: 0.9474
# Epoch 50/120
# 462/462 [==============================] - 48s 103ms/step - loss: 2.5264 - box_loss: 1.8746 - class_loss: 0.6519 - val_loss: 3.6291 - val_box_loss: 2.6613 - val_class_loss: 0.9678
# Epoch 51/120
# 462/462 [==============================] - 48s 103ms/step - loss: 2.5083 - box_loss: 1.8616 - class_loss: 0.6467 - val_loss: 3.5382 - val_box_loss: 2.6221 - val_class_loss: 0.9160
# Epoch 52/120
# 462/462 [==============================] - 48s 103ms/step - loss: 2.4850 - box_loss: 1.8472 - class_loss: 0.6378 - val_loss: 3.5305 - val_box_loss: 2.6118 - val_class_loss: 0.9187
# Epoch 53/120
# 462/462 [==============================] - 48s 103ms/step - loss: 2.4483 - box_loss: 1.8192 - class_loss: 0.6290 - val_loss: 3.5671 - val_box_loss: 2.6413 - val_class_loss: 0.9258
# Epoch 54/120
# 462/462 [==============================] - 48s 103ms/step - loss: 2.4360 - box_loss: 1.8170 - class_loss: 0.6190 - val_loss: 3.5364 - val_box_loss: 2.6344 - val_class_loss: 0.9019
# Epoch 55/120
# 462/462 [==============================] - 48s 103ms/step - loss: 2.4150 - box_loss: 1.7983 - class_loss: 0.6167 - val_loss: 3.5942 - val_box_loss: 2.6485 - val_class_loss: 0.9458
# Epoch 56/120
# 462/462 [==============================] - 48s 103ms/step - loss: 2.3972 - box_loss: 1.7893 - class_loss: 0.6079 - val_loss: 3.6074 - val_box_loss: 2.6793 - val_class_loss: 0.9281
# Epoch 57/120
# 462/462 [==============================] - 48s 103ms/step - loss: 2.3732 - box_loss: 1.7712 - class_loss: 0.6020 - val_loss: 3.6495 - val_box_loss: 2.7025 - val_class_loss: 0.9470
# Epoch 58/120
# 462/462 [==============================] - 48s 103ms/step - loss: 2.3636 - box_loss: 1.7670 - class_loss: 0.5966 - val_loss: 3.6731 - val_box_loss: 2.6935 - val_class_loss: 0.9796
# Epoch 59/120
# 462/462 [==============================] - 48s 103ms/step - loss: 2.3413 - box_loss: 1.7528 - class_loss: 0.5885 - val_loss: 3.6609 - val_box_loss: 2.6985 - val_class_loss: 0.9624
# Epoch 60/120
# 462/462 [==============================] - 48s 103ms/step - loss: 2.3177 - box_loss: 1.7350 - class_loss: 0.5828 - val_loss: 3.6704 - val_box_loss: 2.6981 - val_class_loss: 0.9724
# Epoch 61/120
# 462/462 [==============================] - 48s 103ms/step - loss: 2.3079 - box_loss: 1.7287 - class_loss: 0.5792 - val_loss: 3.7491 - val_box_loss: 2.7600 - val_class_loss: 0.9890
# Epoch 62/120
# 462/462 [==============================] - 48s 103ms/step - loss: 2.2892 - box_loss: 1.7170 - class_loss: 0.5721 - val_loss: 3.7484 - val_box_loss: 2.7392 - val_class_loss: 1.0092
# Epoch 63/120
# 462/462 [==============================] - 48s 103ms/step - loss: 2.2690 - box_loss: 1.7061 - class_loss: 0.5630 - val_loss: 3.8782 - val_box_loss: 2.8399 - val_class_loss: 1.0383
# Epoch 64/120
# 462/462 [==============================] - 48s 103ms/step - loss: 2.2475 - box_loss: 1.6939 - class_loss: 0.5536 - val_loss: 3.8189 - val_box_loss: 2.8032 - val_class_loss: 1.0157
# Epoch 65/120
# 462/462 [==============================] - 48s 103ms/step - loss: 2.2266 - box_loss: 1.6746 - class_loss: 0.5520 - val_loss: 3.7506 - val_box_loss: 2.7560 - val_class_loss: 0.9946
# Epoch 66/120
# 462/462 [==============================] - 48s 103ms/step - loss: 2.2217 - box_loss: 1.6743 - class_loss: 0.5475 - val_loss: 3.8167 - val_box_loss: 2.8055 - val_class_loss: 1.0112
# Epoch 67/120
# 462/462 [==============================] - 48s 103ms/step - loss: 2.2028 - box_loss: 1.6609 - class_loss: 0.5419 - val_loss: 3.8778 - val_box_loss: 2.8239 - val_class_loss: 1.0539
# Epoch 68/120
# 462/462 [==============================] - 48s 103ms/step - loss: 2.1901 - box_loss: 1.6509 - class_loss: 0.5391 - val_loss: 3.9408 - val_box_loss: 2.8853 - val_class_loss: 1.0555
# Epoch 69/120
# 462/462 [==============================] - 48s 103ms/step - loss: 2.1822 - box_loss: 1.6511 - class_loss: 0.5312 - val_loss: 3.9344 - val_box_loss: 2.8429 - val_class_loss: 1.0916
# Epoch 70/120
# 462/462 [==============================] - 48s 103ms/step - loss: 2.1653 - box_loss: 1.6398 - class_loss: 0.5255 - val_loss: 3.9830 - val_box_loss: 2.9028 - val_class_loss: 1.0802
# Epoch 71/120
# 462/462 [==============================] - 48s 103ms/step - loss: 2.1422 - box_loss: 1.6231 - class_loss: 0.5191 - val_loss: 3.8399 - val_box_loss: 2.8049 - val_class_loss: 1.0350
# Epoch 72/120
# 462/462 [==============================] - 48s 103ms/step - loss: 2.1377 - box_loss: 1.6202 - class_loss: 0.5176 - val_loss: 3.9617 - val_box_loss: 2.8829 - val_class_loss: 1.0788
# Epoch 73/120
# 462/462 [==============================] - 48s 103ms/step - loss: 2.1201 - box_loss: 1.6065 - class_loss: 0.5136 - val_loss: 3.8782 - val_box_loss: 2.8402 - val_class_loss: 1.0379
# Epoch 74/120
# 462/462 [==============================] - 48s 103ms/step - loss: 2.1001 - box_loss: 1.5950 - class_loss: 0.5051 - val_loss: 3.9248 - val_box_loss: 2.8734 - val_class_loss: 1.0514
# Epoch 75/120
# 462/462 [==============================] - 48s 102ms/step - loss: 2.0864 - box_loss: 1.5893 - class_loss: 0.4972 - val_loss: 3.8864 - val_box_loss: 2.8419 - val_class_loss: 1.0445
# Epoch 76/120
# 462/462 [==============================] - 48s 103ms/step - loss: 2.0682 - box_loss: 1.5727 - class_loss: 0.4955 - val_loss: 4.0832 - val_box_loss: 2.9581 - val_class_loss: 1.1252
# Epoch 77/120
# 462/462 [==============================] - 48s 103ms/step - loss: 2.0640 - box_loss: 1.5723 - class_loss: 0.4917 - val_loss: 4.0781 - val_box_loss: 2.9696 - val_class_loss: 1.1086
# Epoch 78/120
# 462/462 [==============================] - 48s 103ms/step - loss: 2.0451 - box_loss: 1.5564 - class_loss: 0.4887 - val_loss: 4.0202 - val_box_loss: 2.9324 - val_class_loss: 1.0878
# Epoch 79/120
# 462/462 [==============================] - 48s 103ms/step - loss: 2.0289 - box_loss: 1.5474 - class_loss: 0.4816 - val_loss: 3.9539 - val_box_loss: 2.8634 - val_class_loss: 1.0904
# Epoch 80/120
# 462/462 [==============================] - 48s 103ms/step - loss: 2.0215 - box_loss: 1.5427 - class_loss: 0.4789 - val_loss: 3.9060 - val_box_loss: 2.8632 - val_class_loss: 1.0427
# Epoch 81/120
# 462/462 [==============================] - 48s 103ms/step - loss: 1.9995 - box_loss: 1.5294 - class_loss: 0.4701 - val_loss: 4.0770 - val_box_loss: 2.9757 - val_class_loss: 1.1013
# Epoch 82/120
# 462/462 [==============================] - 48s 103ms/step - loss: 1.9991 - box_loss: 1.5259 - class_loss: 0.4732 - val_loss: 4.0917 - val_box_loss: 2.9748 - val_class_loss: 1.1169
# Epoch 83/120
# 462/462 [==============================] - 48s 103ms/step - loss: 1.9836 - box_loss: 1.5191 - class_loss: 0.4645 - val_loss: 4.1932 - val_box_loss: 3.0367 - val_class_loss: 1.1565
# Epoch 84/120
# 462/462 [==============================] - 48s 103ms/step - loss: 1.9851 - box_loss: 1.5152 - class_loss: 0.4699 - val_loss: 4.1777 - val_box_loss: 2.9187 - val_class_loss: 1.2591
# Epoch 85/120
# 462/462 [==============================] - 48s 103ms/step - loss: 1.9612 - box_loss: 1.5019 - class_loss: 0.4594 - val_loss: 4.1144 - val_box_loss: 2.9841 - val_class_loss: 1.1303
# Epoch 86/120
# 462/462 [==============================] - 48s 104ms/step - loss: 1.9466 - box_loss: 1.4891 - class_loss: 0.4575 - val_loss: 3.9928 - val_box_loss: 2.9256 - val_class_loss: 1.0672
# Epoch 87/120
# 462/462 [==============================] - 48s 104ms/step - loss: 1.9434 - box_loss: 1.4926 - class_loss: 0.4508 - val_loss: 4.0642 - val_box_loss: 2.9495 - val_class_loss: 1.1148
# Epoch 88/120
# 462/462 [==============================] - 48s 103ms/step - loss: 1.9253 - box_loss: 1.4755 - class_loss: 0.4497 - val_loss: 3.9450 - val_box_loss: 2.8907 - val_class_loss: 1.0542
# Epoch 89/120
# 462/462 [==============================] - 48s 103ms/step - loss: 1.9078 - box_loss: 1.4633 - class_loss: 0.4445 - val_loss: 4.1213 - val_box_loss: 2.9957 - val_class_loss: 1.1256
# Epoch 90/120
# 462/462 [==============================] - 48s 103ms/step - loss: 1.9103 - box_loss: 1.4670 - class_loss: 0.4433 - val_loss: 3.9930 - val_box_loss: 2.9163 - val_class_loss: 1.0768
# Epoch 91/120
# 462/462 [==============================] - 48s 104ms/step - loss: 1.9058 - box_loss: 1.4677 - class_loss: 0.4381 - val_loss: 4.1894 - val_box_loss: 3.0345 - val_class_loss: 1.1549
# Epoch 92/120
# 462/462 [==============================] - 48s 103ms/step - loss: 1.8917 - box_loss: 1.4548 - class_loss: 0.4369 - val_loss: 3.9867 - val_box_loss: 2.9101 - val_class_loss: 1.0765
# Epoch 93/120
# 462/462 [==============================] - 48s 104ms/step - loss: 1.8778 - box_loss: 1.4450 - class_loss: 0.4328 - val_loss: 4.1126 - val_box_loss: 2.9814 - val_class_loss: 1.1311
# Epoch 94/120
# 462/462 [==============================] - 48s 103ms/step - loss: 1.8487 - box_loss: 1.4210 - class_loss: 0.4277 - val_loss: 3.9865 - val_box_loss: 2.9212 - val_class_loss: 1.0653
# Epoch 95/120
# 462/462 [==============================] - 48s 103ms/step - loss: 1.8535 - box_loss: 1.4267 - class_loss: 0.4268 - val_loss: 4.0149 - val_box_loss: 2.9378 - val_class_loss: 1.0771
# Epoch 96/120
# 462/462 [==============================] - 48s 103ms/step - loss: 1.8495 - box_loss: 1.4265 - class_loss: 0.4230 - val_loss: 4.1152 - val_box_loss: 2.9908 - val_class_loss: 1.1244
# Epoch 97/120
# 462/462 [==============================] - 48s 103ms/step - loss: 1.8301 - box_loss: 1.4117 - class_loss: 0.4184 - val_loss: 4.0937 - val_box_loss: 2.9485 - val_class_loss: 1.1451
# Epoch 98/120
# 462/462 [==============================] - 48s 103ms/step - loss: 1.8328 - box_loss: 1.4141 - class_loss: 0.4187 - val_loss: 4.1808 - val_box_loss: 3.0383 - val_class_loss: 1.1425
# Epoch 99/120
# 462/462 [==============================] - 48s 103ms/step - loss: 1.8189 - box_loss: 1.4052 - class_loss: 0.4138 - val_loss: 4.1346 - val_box_loss: 3.0203 - val_class_loss: 1.1143
# Epoch 100/120
# 462/462 [==============================] - 48s 103ms/step - loss: 1.8118 - box_loss: 1.3995 - class_loss: 0.4123 - val_loss: 4.1472 - val_box_loss: 3.0133 - val_class_loss: 1.1338
# Epoch 101/120
# 462/462 [==============================] - 48s 103ms/step - loss: 1.7940 - box_loss: 1.3872 - class_loss: 0.4068 - val_loss: 4.2377 - val_box_loss: 3.0730 - val_class_loss: 1.1646
# Epoch 102/120
# 462/462 [==============================] - 48s 103ms/step - loss: 1.7988 - box_loss: 1.3922 - class_loss: 0.4066 - val_loss: 4.2355 - val_box_loss: 3.0792 - val_class_loss: 1.1564
# Epoch 103/120
# 462/462 [==============================] - 48s 103ms/step - loss: 1.7907 - box_loss: 1.3867 - class_loss: 0.4040 - val_loss: 4.0834 - val_box_loss: 2.9682 - val_class_loss: 1.1152
# Epoch 104/120
# 462/462 [==============================] - 48s 103ms/step - loss: 1.7763 - box_loss: 1.3767 - class_loss: 0.3997 - val_loss: 4.0920 - val_box_loss: 2.9799 - val_class_loss: 1.1121
# Epoch 105/120
# 462/462 [==============================] - 48s 103ms/step - loss: 1.7757 - box_loss: 1.3761 - class_loss: 0.3996 - val_loss: 4.1253 - val_box_loss: 3.0036 - val_class_loss: 1.1217
# Epoch 106/120
# 462/462 [==============================] - 48s 103ms/step - loss: 1.7754 - box_loss: 1.3773 - class_loss: 0.3982 - val_loss: 4.1230 - val_box_loss: 2.9767 - val_class_loss: 1.1463
# Epoch 107/120
# 462/462 [==============================] - 48s 103ms/step - loss: 1.7661 - box_loss: 1.3713 - class_loss: 0.3948 - val_loss: 4.0340 - val_box_loss: 2.9476 - val_class_loss: 1.0864
# Epoch 108/120
# 462/462 [==============================] - 48s 103ms/step - loss: 1.7460 - box_loss: 1.3563 - class_loss: 0.3897 - val_loss: 4.1283 - val_box_loss: 3.0168 - val_class_loss: 1.1115
# Epoch 109/120
# 462/462 [==============================] - 48s 103ms/step - loss: 1.7303 - box_loss: 1.3431 - class_loss: 0.3873 - val_loss: 4.0411 - val_box_loss: 2.9770 - val_class_loss: 1.0641
# Epoch 110/120
# 462/462 [==============================] - 48s 103ms/step - loss: 1.7326 - box_loss: 1.3488 - class_loss: 0.3839 - val_loss: 4.1337 - val_box_loss: 3.0003 - val_class_loss: 1.1334
# Epoch 111/120
# 462/462 [==============================] - 48s 103ms/step - loss: 1.7281 - box_loss: 1.3448 - class_loss: 0.3833 - val_loss: 4.1936 - val_box_loss: 3.0347 - val_class_loss: 1.1589
# Epoch 112/120
# 462/462 [==============================] - 48s 103ms/step - loss: 1.7172 - box_loss: 1.3397 - class_loss: 0.3775 - val_loss: 4.1079 - val_box_loss: 2.9897 - val_class_loss: 1.1182
# Epoch 113/120
# 462/462 [==============================] - 48s 103ms/step - loss: 1.7239 - box_loss: 1.3421 - class_loss: 0.3817 - val_loss: 4.1273 - val_box_loss: 2.9943 - val_class_loss: 1.1330
# Epoch 114/120
# 462/462 [==============================] - 48s 103ms/step - loss: 1.7010 - box_loss: 1.3242 - class_loss: 0.3768 - val_loss: 4.1006 - val_box_loss: 2.9760 - val_class_loss: 1.1245
# Epoch 115/120
# 462/462 [==============================] - 48s 103ms/step - loss: 1.7098 - box_loss: 1.3338 - class_loss: 0.3760 - val_loss: 4.1773 - val_box_loss: 3.0124 - val_class_loss: 1.1650
# Epoch 116/120
# 462/462 [==============================] - 48s 103ms/step - loss: 1.6983 - box_loss: 1.3241 - class_loss: 0.3742 - val_loss: 4.1647 - val_box_loss: 3.0499 - val_class_loss: 1.1148
# Epoch 117/120
# 462/462 [==============================] - 48s 103ms/step - loss: 1.7013 - box_loss: 1.3283 - class_loss: 0.3730 - val_loss: 4.1656 - val_box_loss: 3.0027 - val_class_loss: 1.1630
# Epoch 118/120
# 462/462 [==============================] - 48s 103ms/step - loss: 1.6867 - box_loss: 1.3180 - class_loss: 0.3687 - val_loss: 4.2491 - val_box_loss: 3.0881 - val_class_loss: 1.1610
# Epoch 119/120
# 462/462 [==============================] - 48s 103ms/step - loss: 1.6863 - box_loss: 1.3176 - class_loss: 0.3687 - val_loss: 4.0005 - val_box_loss: 2.9198 - val_class_loss: 1.0807
# Epoch 120/120
# 462/462 [==============================] - 48s 103ms/step - loss: 1.6872 - box_loss: 1.3185 - class_loss: 0.3688 - val_loss: 4.1384 - val_box_loss: 3.0172 - val_class_loss: 1.1212
# /usr/local/lib/python3.10/dist-packages/keras_cv/src/models/task.py:43: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   return id(getattr(self, attr)) not in self._functional_layer_ids
# /usr/local/lib/python3.10/dist-packages/keras_cv/src/models/task.py:43: UserWarning: `layer.updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   return id(getattr(self, attr)) not in self._functional_layer_ids

# %%
#plot loss
import matplotlib.pyplot as plt
plt.plot(hist.history['loss'], label='Train')
plt.plot(hist.history['val_loss'], label = 'Validation')
plt.legend()
plt.title('Loss')
plt.show()
plt.savefig('/content/drive/MyDrive/Brain-Tumor-Detection/reports/figures/Loss')
#plot Accuracy
plt.plot(hist.history['box_loss'], label='Train')
plt.plot(hist.history['val_box_loss'], label = 'Validation')
plt.legend()
plt.title('Box Loss')
plt.show()
plt.savefig('/content/drive/MyDrive/Brain-Tumor-Detection/reports/figures/Box Loss')

#plot classification loss
plt.plot(hist.history['class_loss'], label='Train')
plt.plot(hist.history['val_class_loss'], label = 'Validation')
plt.legend()
plt.title('Classification Loss')
plt.show()
plt.savefig('/content/drive/MyDrive/Brain-Tumor-Detection/reports/figures/Classification Loss')

# %%
def visualize(inputs, value_range, rows, cols, bounding_box_format):
  inputs =next(iter(inputs.take(1)))
  image, bounding_boxes = inputs[0], inputs[1]

  keras_cv.visualization.plot_bounding_box_gallery(
      image,
      value_range=value_range,
      rows=rows,
      cols=cols,
      y_true=bounding_boxes,
      scale=8,
      font_scale=0.8,
      line_thickness=1,
      dpi = 300,
      bounding_box_format=bounding_box_format,
      class_mapping=mapping,
      true_color = (192, 57, 43)
  )


visualize(train_dataset,
            bounding_box_format = "xyxy",
            value_range=(0,255),
            rows=2,
            cols=2)

# %%
6891
model = load_saved_model('/content/drive/MyDrive/Brain-Tumor-Detection/models/TumorDetectionmodel.keras')
print(model.summary())
# Out:
# WARNING:tensorflow:`compile()` was not called as part of model loading because the model's `compile()` method is custom. All subclassed Models that have `compile()` overridden should also override `get_compile_config()` and `compile_from_config(config)`. Alternatively, you can call `compile()` manually after loading.
# Model: "yolov8_detector_12"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_26 (InputLayer)       [(None, None, None, 3)]      0         []
#
#  model_12 (Functional)       {'P3': (None, None, None,    1277680   ['input_26[0][0]']
#                              64),
#                               'P4': (None, None, None,
#                              128),
#                               'P5': (None, None, None,
#                              256)}
#
#  tf.repeat_48 (TFOpLambda)   (None, None, None, 256)      0         ['model_12[0][2]']
#
#  tf.repeat_49 (TFOpLambda)   (None, None, None, 256)      0         ['tf.repeat_48[0][0]']
#
#  tf.concat_209 (TFOpLambda)  (None, None, None, 384)      0         ['tf.repeat_49[0][0]',
#                                                                      'model_12[0][1]']
#
#  pa_fpn_p4p5_pre_conv (Conv  (None, None, None, 128)      49152     ['tf.concat_209[0][0]']
#  2D)
#
#  pa_fpn_p4p5_pre_bn (BatchN  (None, None, None, 128)      512       ['pa_fpn_p4p5_pre_conv[0][0]']
#  ormalization)
#
#  pa_fpn_p4p5_pre (Activatio  (None, None, None, 128)      0         ['pa_fpn_p4p5_pre_bn[0][0]']
#  n)
#
#  tf.split_100 (TFOpLambda)   [(None, None, None, 64),     0         ['pa_fpn_p4p5_pre[0][0]']
#                               (None, None, None, 64)]
#
#  pa_fpn_p4p5_pre_0_1_pad (Z  (None, None, None, 64)       0         ['tf.split_100[0][1]']
#  eroPadding2D)
#
#  pa_fpn_p4p5_pre_0_1_conv (  (None, None, None, 64)       36864     ['pa_fpn_p4p5_pre_0_1_pad[0][0
#  Conv2D)                                                            ]']
#
#  pa_fpn_p4p5_pre_0_1_bn (Ba  (None, None, None, 64)       256       ['pa_fpn_p4p5_pre_0_1_conv[0][
#  tchNormalization)                                                  0]']
#
#  pa_fpn_p4p5_pre_0_1 (Activ  (None, None, None, 64)       0         ['pa_fpn_p4p5_pre_0_1_bn[0][0]
#  ation)                                                             ']
#
#  pa_fpn_p4p5_pre_0_2_pad (Z  (None, None, None, 64)       0         ['pa_fpn_p4p5_pre_0_1[0][0]']
#  eroPadding2D)
#
#  pa_fpn_p4p5_pre_0_2_conv (  (None, None, None, 64)       36864     ['pa_fpn_p4p5_pre_0_2_pad[0][0
#  Conv2D)                                                            ]']
#
#  pa_fpn_p4p5_pre_0_2_bn (Ba  (None, None, None, 64)       256       ['pa_fpn_p4p5_pre_0_2_conv[0][
#  tchNormalization)                                                  0]']
#
#  pa_fpn_p4p5_pre_0_2 (Activ  (None, None, None, 64)       0         ['pa_fpn_p4p5_pre_0_2_bn[0][0]
#  ation)                                                             ']
#
#  tf.concat_210 (TFOpLambda)  (None, None, None, 192)      0         ['tf.split_100[0][0]',
#                                                                      'tf.split_100[0][1]',
#                                                                      'pa_fpn_p4p5_pre_0_2[0][0]']
#
#  pa_fpn_p4p5_output_conv (C  (None, None, None, 128)      24576     ['tf.concat_210[0][0]']
#  onv2D)
#
#  pa_fpn_p4p5_output_bn (Bat  (None, None, None, 128)      512       ['pa_fpn_p4p5_output_conv[0][0
#  chNormalization)                                                   ]']
#
#  pa_fpn_p4p5_output (Activa  (None, None, None, 128)      0         ['pa_fpn_p4p5_output_bn[0][0]'
#  tion)                                                              ]
#
#  tf.repeat_50 (TFOpLambda)   (None, None, None, 128)      0         ['pa_fpn_p4p5_output[0][0]']
#
#  tf.repeat_51 (TFOpLambda)   (None, None, None, 128)      0         ['tf.repeat_50[0][0]']
#
#  tf.concat_211 (TFOpLambda)  (None, None, None, 192)      0         ['tf.repeat_51[0][0]',
#                                                                      'model_12[0][0]']
#
#  pa_fpn_p3p4p5_pre_conv (Co  (None, None, None, 64)       12288     ['tf.concat_211[0][0]']
#  nv2D)
#
#  pa_fpn_p3p4p5_pre_bn (Batc  (None, None, None, 64)       256       ['pa_fpn_p3p4p5_pre_conv[0][0]
#  hNormalization)                                                    ']
#
#  pa_fpn_p3p4p5_pre (Activat  (None, None, None, 64)       0         ['pa_fpn_p3p4p5_pre_bn[0][0]']
#  ion)
#
#  tf.split_101 (TFOpLambda)   [(None, None, None, 32),     0         ['pa_fpn_p3p4p5_pre[0][0]']
#                               (None, None, None, 32)]
#
#  pa_fpn_p3p4p5_pre_0_1_pad   (None, None, None, 32)       0         ['tf.split_101[0][1]']
#  (ZeroPadding2D)
#
#  pa_fpn_p3p4p5_pre_0_1_conv  (None, None, None, 32)       9216      ['pa_fpn_p3p4p5_pre_0_1_pad[0]
#   (Conv2D)                                                          [0]']
#
#  pa_fpn_p3p4p5_pre_0_1_bn (  (None, None, None, 32)       128       ['pa_fpn_p3p4p5_pre_0_1_conv[0
#  BatchNormalization)                                                ][0]']
#
#  pa_fpn_p3p4p5_pre_0_1 (Act  (None, None, None, 32)       0         ['pa_fpn_p3p4p5_pre_0_1_bn[0][
#  ivation)                                                           0]']
#
#  pa_fpn_p3p4p5_pre_0_2_pad   (None, None, None, 32)       0         ['pa_fpn_p3p4p5_pre_0_1[0][0]'
#  (ZeroPadding2D)                                                    ]
#
#  pa_fpn_p3p4p5_pre_0_2_conv  (None, None, None, 32)       9216      ['pa_fpn_p3p4p5_pre_0_2_pad[0]
#   (Conv2D)                                                          [0]']
#
#  pa_fpn_p3p4p5_pre_0_2_bn (  (None, None, None, 32)       128       ['pa_fpn_p3p4p5_pre_0_2_conv[0
#  BatchNormalization)                                                ][0]']
#
#  pa_fpn_p3p4p5_pre_0_2 (Act  (None, None, None, 32)       0         ['pa_fpn_p3p4p5_pre_0_2_bn[0][
#  ivation)                                                           0]']
#
#  tf.concat_212 (TFOpLambda)  (None, None, None, 96)       0         ['tf.split_101[0][0]',
#                                                                      'tf.split_101[0][1]',
#                                                                      'pa_fpn_p3p4p5_pre_0_2[0][0]'
#                                                                     ]
#
#  pa_fpn_p3p4p5_output_conv   (None, None, None, 64)       6144      ['tf.concat_212[0][0]']
#  (Conv2D)
#
#  pa_fpn_p3p4p5_output_bn (B  (None, None, None, 64)       256       ['pa_fpn_p3p4p5_output_conv[0]
#  atchNormalization)                                                 [0]']
#
#  pa_fpn_p3p4p5_output (Acti  (None, None, None, 64)       0         ['pa_fpn_p3p4p5_output_bn[0][0
#  vation)                                                            ]']
#
#  pa_fpn_p3p4p5_downsample1_  (None, None, None, 64)       0         ['pa_fpn_p3p4p5_output[0][0]']
#  pad (ZeroPadding2D)
#
#  pa_fpn_p3p4p5_downsample1_  (None, None, None, 64)       36864     ['pa_fpn_p3p4p5_downsample1_pa
#  conv (Conv2D)                                                      d[0][0]']
#
#  pa_fpn_p3p4p5_downsample1_  (None, None, None, 64)       256       ['pa_fpn_p3p4p5_downsample1_co
#  bn (BatchNormalization)                                            nv[0][0]']
#
#  pa_fpn_p3p4p5_downsample1   (None, None, None, 64)       0         ['pa_fpn_p3p4p5_downsample1_bn
#  (Activation)                                                       [0][0]']
#
#  tf.concat_213 (TFOpLambda)  (None, None, None, 192)      0         ['pa_fpn_p3p4p5_downsample1[0]
#                                                                     [0]',
#                                                                      'pa_fpn_p4p5_output[0][0]']
#
#  pa_fpn_p3p4p5_downsample1_  (None, None, None, 128)      24576     ['tf.concat_213[0][0]']
#  block_pre_conv (Conv2D)
#
#  pa_fpn_p3p4p5_downsample1_  (None, None, None, 128)      512       ['pa_fpn_p3p4p5_downsample1_bl
#  block_pre_bn (BatchNormali                                         ock_pre_conv[0][0]']
#  zation)
#
#  pa_fpn_p3p4p5_downsample1_  (None, None, None, 128)      0         ['pa_fpn_p3p4p5_downsample1_bl
#  block_pre (Activation)                                             ock_pre_bn[0][0]']
#
#  tf.split_102 (TFOpLambda)   [(None, None, None, 64),     0         ['pa_fpn_p3p4p5_downsample1_bl
#                               (None, None, None, 64)]               ock_pre[0][0]']
#
#  pa_fpn_p3p4p5_downsample1_  (None, None, None, 64)       0         ['tf.split_102[0][1]']
#  block_pre_0_1_pad (ZeroPad
#  ding2D)
#
#  pa_fpn_p3p4p5_downsample1_  (None, None, None, 64)       36864     ['pa_fpn_p3p4p5_downsample1_bl
#  block_pre_0_1_conv (Conv2D                                         ock_pre_0_1_pad[0][0]']
#  )
#
#  pa_fpn_p3p4p5_downsample1_  (None, None, None, 64)       256       ['pa_fpn_p3p4p5_downsample1_bl
#  block_pre_0_1_bn (BatchNor                                         ock_pre_0_1_conv[0][0]']
#  malization)
#
#  pa_fpn_p3p4p5_downsample1_  (None, None, None, 64)       0         ['pa_fpn_p3p4p5_downsample1_bl
#  block_pre_0_1 (Activation)                                         ock_pre_0_1_bn[0][0]']
#
#  pa_fpn_p3p4p5_downsample1_  (None, None, None, 64)       0         ['pa_fpn_p3p4p5_downsample1_bl
#  block_pre_0_2_pad (ZeroPad                                         ock_pre_0_1[0][0]']
#  ding2D)
#
#  pa_fpn_p3p4p5_downsample1_  (None, None, None, 64)       36864     ['pa_fpn_p3p4p5_downsample1_bl
#  block_pre_0_2_conv (Conv2D                                         ock_pre_0_2_pad[0][0]']
#  )
#
#  pa_fpn_p3p4p5_downsample1_  (None, None, None, 64)       256       ['pa_fpn_p3p4p5_downsample1_bl
#  block_pre_0_2_bn (BatchNor                                         ock_pre_0_2_conv[0][0]']
#  malization)
#
#  pa_fpn_p3p4p5_downsample1_  (None, None, None, 64)       0         ['pa_fpn_p3p4p5_downsample1_bl
#  block_pre_0_2 (Activation)                                         ock_pre_0_2_bn[0][0]']
#
#  pa_fpn_p3p4p5_downsample1_  (None, None, None, 64)       0         ['pa_fpn_p3p4p5_downsample1_bl
#  block_pre_1_1_pad (ZeroPad                                         ock_pre_0_2[0][0]']
#  ding2D)
#
#  pa_fpn_p3p4p5_downsample1_  (None, None, None, 64)       36864     ['pa_fpn_p3p4p5_downsample1_bl
#  block_pre_1_1_conv (Conv2D                                         ock_pre_1_1_pad[0][0]']
#  )
#
#  pa_fpn_p3p4p5_downsample1_  (None, None, None, 64)       256       ['pa_fpn_p3p4p5_downsample1_bl
#  block_pre_1_1_bn (BatchNor                                         ock_pre_1_1_conv[0][0]']
#  malization)
#
#  pa_fpn_p3p4p5_downsample1_  (None, None, None, 64)       0         ['pa_fpn_p3p4p5_downsample1_bl
#  block_pre_1_1 (Activation)                                         ock_pre_1_1_bn[0][0]']
#
#  pa_fpn_p3p4p5_downsample1_  (None, None, None, 64)       0         ['pa_fpn_p3p4p5_downsample1_bl
#  block_pre_1_2_pad (ZeroPad                                         ock_pre_1_1[0][0]']
#  ding2D)
#
#  pa_fpn_p3p4p5_downsample1_  (None, None, None, 64)       36864     ['pa_fpn_p3p4p5_downsample1_bl
#  block_pre_1_2_conv (Conv2D                                         ock_pre_1_2_pad[0][0]']
#  )
#
#  pa_fpn_p3p4p5_downsample1_  (None, None, None, 64)       256       ['pa_fpn_p3p4p5_downsample1_bl
#  block_pre_1_2_bn (BatchNor                                         ock_pre_1_2_conv[0][0]']
#  malization)
#
#  pa_fpn_p3p4p5_downsample1_  (None, None, None, 64)       0         ['pa_fpn_p3p4p5_downsample1_bl
#  block_pre_1_2 (Activation)                                         ock_pre_1_2_bn[0][0]']
#
#  tf.concat_214 (TFOpLambda)  (None, None, None, 256)      0         ['tf.split_102[0][0]',
#                                                                      'tf.split_102[0][1]',
#                                                                      'pa_fpn_p3p4p5_downsample1_bl
#                                                                     ock_pre_0_2[0][0]',
#                                                                      'pa_fpn_p3p4p5_downsample1_bl
#                                                                     ock_pre_1_2[0][0]']
#
#  pa_fpn_p3p4p5_downsample1_  (None, None, None, 128)      32768     ['tf.concat_214[0][0]']
#  block_output_conv (Conv2D)
#
#  pa_fpn_p3p4p5_downsample1_  (None, None, None, 128)      512       ['pa_fpn_p3p4p5_downsample1_bl
#  block_output_bn (BatchNorm                                         ock_output_conv[0][0]']
#  alization)
#
#  pa_fpn_p3p4p5_downsample1_  (None, None, None, 128)      0         ['pa_fpn_p3p4p5_downsample1_bl
#  block_output (Activation)                                          ock_output_bn[0][0]']
#
#  pa_fpn_p3p4p5_downsample2_  (None, None, None, 128)      0         ['pa_fpn_p3p4p5_downsample1_bl
#  pad (ZeroPadding2D)                                                ock_output[0][0]']
#
#  pa_fpn_p3p4p5_downsample2_  (None, None, None, 128)      147456    ['pa_fpn_p3p4p5_downsample2_pa
#  conv (Conv2D)                                                      d[0][0]']
#
#  pa_fpn_p3p4p5_downsample2_  (None, None, None, 128)      512       ['pa_fpn_p3p4p5_downsample2_co
#  bn (BatchNormalization)                                            nv[0][0]']
#
#  pa_fpn_p3p4p5_downsample2   (None, None, None, 128)      0         ['pa_fpn_p3p4p5_downsample2_bn
#  (Activation)                                                       [0][0]']
#
#  tf.concat_215 (TFOpLambda)  (None, None, None, 384)      0         ['pa_fpn_p3p4p5_downsample2[0]
#                                                                     [0]',
#                                                                      'model_12[0][2]']
#
#  pa_fpn_p3p4p5_downsample2_  (None, None, None, 256)      98304     ['tf.concat_215[0][0]']
#  block_pre_conv (Conv2D)
#
#  pa_fpn_p3p4p5_downsample2_  (None, None, None, 256)      1024      ['pa_fpn_p3p4p5_downsample2_bl
#  block_pre_bn (BatchNormali                                         ock_pre_conv[0][0]']
#  zation)
#
#  pa_fpn_p3p4p5_downsample2_  (None, None, None, 256)      0         ['pa_fpn_p3p4p5_downsample2_bl
#  block_pre (Activation)                                             ock_pre_bn[0][0]']
#
#  tf.split_103 (TFOpLambda)   [(None, None, None, 128),    0         ['pa_fpn_p3p4p5_downsample2_bl
#                               (None, None, None, 128)]              ock_pre[0][0]']
#
#  pa_fpn_p3p4p5_downsample2_  (None, None, None, 128)      0         ['tf.split_103[0][1]']
#  block_pre_0_1_pad (ZeroPad
#  ding2D)
#
#  pa_fpn_p3p4p5_downsample2_  (None, None, None, 128)      147456    ['pa_fpn_p3p4p5_downsample2_bl
#  block_pre_0_1_conv (Conv2D                                         ock_pre_0_1_pad[0][0]']
#  )
#
#  pa_fpn_p3p4p5_downsample2_  (None, None, None, 128)      512       ['pa_fpn_p3p4p5_downsample2_bl
#  block_pre_0_1_bn (BatchNor                                         ock_pre_0_1_conv[0][0]']
#  malization)
#
#  pa_fpn_p3p4p5_downsample2_  (None, None, None, 128)      0         ['pa_fpn_p3p4p5_downsample2_bl
#  block_pre_0_1 (Activation)                                         ock_pre_0_1_bn[0][0]']
#
#  pa_fpn_p3p4p5_downsample2_  (None, None, None, 128)      0         ['pa_fpn_p3p4p5_downsample2_bl
#  block_pre_0_2_pad (ZeroPad                                         ock_pre_0_1[0][0]']
#  ding2D)
#
#  pa_fpn_p3p4p5_downsample2_  (None, None, None, 128)      147456    ['pa_fpn_p3p4p5_downsample2_bl
#  block_pre_0_2_conv (Conv2D                                         ock_pre_0_2_pad[0][0]']
#  )
#
#  pa_fpn_p3p4p5_downsample2_  (None, None, None, 128)      512       ['pa_fpn_p3p4p5_downsample2_bl
#  block_pre_0_2_bn (BatchNor                                         ock_pre_0_2_conv[0][0]']
#  malization)
#
#  pa_fpn_p3p4p5_downsample2_  (None, None, None, 128)      0         ['pa_fpn_p3p4p5_downsample2_bl
#  block_pre_0_2 (Activation)                                         ock_pre_0_2_bn[0][0]']
#
#  pa_fpn_p3p4p5_downsample2_  (None, None, None, 128)      0         ['pa_fpn_p3p4p5_downsample2_bl
#  block_pre_1_1_pad (ZeroPad                                         ock_pre_0_2[0][0]']
#  ding2D)
#
#  pa_fpn_p3p4p5_downsample2_  (None, None, None, 128)      147456    ['pa_fpn_p3p4p5_downsample2_bl
#  block_pre_1_1_conv (Conv2D                                         ock_pre_1_1_pad[0][0]']
#  )
#
#  pa_fpn_p3p4p5_downsample2_  (None, None, None, 128)      512       ['pa_fpn_p3p4p5_downsample2_bl
#  block_pre_1_1_bn (BatchNor                                         ock_pre_1_1_conv[0][0]']
#  malization)
#
#  pa_fpn_p3p4p5_downsample2_  (None, None, None, 128)      0         ['pa_fpn_p3p4p5_downsample2_bl
#  block_pre_1_1 (Activation)                                         ock_pre_1_1_bn[0][0]']
#
#  pa_fpn_p3p4p5_downsample2_  (None, None, None, 128)      0         ['pa_fpn_p3p4p5_downsample2_bl
#  block_pre_1_2_pad (ZeroPad                                         ock_pre_1_1[0][0]']
#  ding2D)
#
#  pa_fpn_p3p4p5_downsample2_  (None, None, None, 128)      147456    ['pa_fpn_p3p4p5_downsample2_bl
#  block_pre_1_2_conv (Conv2D                                         ock_pre_1_2_pad[0][0]']
#  )
#
#  pa_fpn_p3p4p5_downsample2_  (None, None, None, 128)      512       ['pa_fpn_p3p4p5_downsample2_bl
#  block_pre_1_2_bn (BatchNor                                         ock_pre_1_2_conv[0][0]']
#  malization)
#
#  pa_fpn_p3p4p5_downsample2_  (None, None, None, 128)      0         ['pa_fpn_p3p4p5_downsample2_bl
#  block_pre_1_2 (Activation)                                         ock_pre_1_2_bn[0][0]']
#
#  tf.concat_216 (TFOpLambda)  (None, None, None, 512)      0         ['tf.split_103[0][0]',
#                                                                      'tf.split_103[0][1]',
#                                                                      'pa_fpn_p3p4p5_downsample2_bl
#                                                                     ock_pre_0_2[0][0]',
#                                                                      'pa_fpn_p3p4p5_downsample2_bl
#                                                                     ock_pre_1_2[0][0]']
#
#  pa_fpn_p3p4p5_downsample2_  (None, None, None, 256)      131072    ['tf.concat_216[0][0]']
#  block_output_conv (Conv2D)
#
#  pa_fpn_p3p4p5_downsample2_  (None, None, None, 256)      1024      ['pa_fpn_p3p4p5_downsample2_bl
#  block_output_bn (BatchNorm                                         ock_output_conv[0][0]']
#  alization)
#
#  pa_fpn_p3p4p5_downsample2_  (None, None, None, 256)      0         ['pa_fpn_p3p4p5_downsample2_bl
#  block_output (Activation)                                          ock_output_bn[0][0]']
#
#  yolo_v8_head_1_class_1_pad  (None, None, None, 64)       0         ['pa_fpn_p3p4p5_output[0][0]']
#   (ZeroPadding2D)
#
#  yolo_v8_head_2_class_1_pad  (None, None, None, 128)      0         ['pa_fpn_p3p4p5_downsample1_bl
#   (ZeroPadding2D)                                                   ock_output[0][0]']
#
#  yolo_v8_head_3_class_1_pad  (None, None, None, 256)      0         ['pa_fpn_p3p4p5_downsample2_bl
#   (ZeroPadding2D)                                                   ock_output[0][0]']
#
#  yolo_v8_head_1_box_1_pad (  (None, None, None, 64)       0         ['pa_fpn_p3p4p5_output[0][0]']
#  ZeroPadding2D)
#
#  yolo_v8_head_1_class_1_con  (None, None, None, 64)       36864     ['yolo_v8_head_1_class_1_pad[0
#  v (Conv2D)                                                         ][0]']
#
#  yolo_v8_head_2_box_1_pad (  (None, None, None, 128)      0         ['pa_fpn_p3p4p5_downsample1_bl
#  ZeroPadding2D)                                                     ock_output[0][0]']
#
#  yolo_v8_head_2_class_1_con  (None, None, None, 64)       73728     ['yolo_v8_head_2_class_1_pad[0
#  v (Conv2D)                                                         ][0]']
#
#  yolo_v8_head_3_box_1_pad (  (None, None, None, 256)      0         ['pa_fpn_p3p4p5_downsample2_bl
#  ZeroPadding2D)                                                     ock_output[0][0]']
#
#  yolo_v8_head_3_class_1_con  (None, None, None, 64)       147456    ['yolo_v8_head_3_class_1_pad[0
#  v (Conv2D)                                                         ][0]']
#
#  yolo_v8_head_1_box_1_conv   (None, None, None, 64)       36864     ['yolo_v8_head_1_box_1_pad[0][
#  (Conv2D)                                                           0]']
#
#  yolo_v8_head_1_class_1_bn   (None, None, None, 64)       256       ['yolo_v8_head_1_class_1_conv[
#  (BatchNormalization)                                               0][0]']
#
#  yolo_v8_head_2_box_1_conv   (None, None, None, 64)       73728     ['yolo_v8_head_2_box_1_pad[0][
#  (Conv2D)                                                           0]']
#
#  yolo_v8_head_2_class_1_bn   (None, None, None, 64)       256       ['yolo_v8_head_2_class_1_conv[
#  (BatchNormalization)                                               0][0]']
#
#  yolo_v8_head_3_box_1_conv   (None, None, None, 64)       147456    ['yolo_v8_head_3_box_1_pad[0][
#  (Conv2D)                                                           0]']
#
#  yolo_v8_head_3_class_1_bn   (None, None, None, 64)       256       ['yolo_v8_head_3_class_1_conv[
#  (BatchNormalization)                                               0][0]']
#
#  yolo_v8_head_1_box_1_bn (B  (None, None, None, 64)       256       ['yolo_v8_head_1_box_1_conv[0]
#  atchNormalization)                                                 [0]']
#
#  yolo_v8_head_1_class_1 (Ac  (None, None, None, 64)       0         ['yolo_v8_head_1_class_1_bn[0]
#  tivation)                                                          [0]']
#
#  yolo_v8_head_2_box_1_bn (B  (None, None, None, 64)       256       ['yolo_v8_head_2_box_1_conv[0]
#  atchNormalization)                                                 [0]']
#
#  yolo_v8_head_2_class_1 (Ac  (None, None, None, 64)       0         ['yolo_v8_head_2_class_1_bn[0]
#  tivation)                                                          [0]']
#
#  yolo_v8_head_3_box_1_bn (B  (None, None, None, 64)       256       ['yolo_v8_head_3_box_1_conv[0]
#  atchNormalization)                                                 [0]']
#
#  yolo_v8_head_3_class_1 (Ac  (None, None, None, 64)       0         ['yolo_v8_head_3_class_1_bn[0]
#  tivation)                                                          [0]']
#
#  yolo_v8_head_1_box_1 (Acti  (None, None, None, 64)       0         ['yolo_v8_head_1_box_1_bn[0][0
#  vation)                                                            ]']
#
#  yolo_v8_head_1_class_2_pad  (None, None, None, 64)       0         ['yolo_v8_head_1_class_1[0][0]
#   (ZeroPadding2D)                                                   ']
#
#  yolo_v8_head_2_box_1 (Acti  (None, None, None, 64)       0         ['yolo_v8_head_2_box_1_bn[0][0
#  vation)                                                            ]']
#
#  yolo_v8_head_2_class_2_pad  (None, None, None, 64)       0         ['yolo_v8_head_2_class_1[0][0]
#   (ZeroPadding2D)                                                   ']
#
#  yolo_v8_head_3_box_1 (Acti  (None, None, None, 64)       0         ['yolo_v8_head_3_box_1_bn[0][0
#  vation)                                                            ]']
#
#  yolo_v8_head_3_class_2_pad  (None, None, None, 64)       0         ['yolo_v8_head_3_class_1[0][0]
#   (ZeroPadding2D)                                                   ']
#
#  yolo_v8_head_1_box_2_pad (  (None, None, None, 64)       0         ['yolo_v8_head_1_box_1[0][0]']
#  ZeroPadding2D)
#
#  yolo_v8_head_1_class_2_con  (None, None, None, 64)       36864     ['yolo_v8_head_1_class_2_pad[0
#  v (Conv2D)                                                         ][0]']
#
#  yolo_v8_head_2_box_2_pad (  (None, None, None, 64)       0         ['yolo_v8_head_2_box_1[0][0]']
#  ZeroPadding2D)
#
#  yolo_v8_head_2_class_2_con  (None, None, None, 64)       36864     ['yolo_v8_head_2_class_2_pad[0
#  v (Conv2D)                                                         ][0]']
#
#  yolo_v8_head_3_box_2_pad (  (None, None, None, 64)       0         ['yolo_v8_head_3_box_1[0][0]']
#  ZeroPadding2D)
#
#  yolo_v8_head_3_class_2_con  (None, None, None, 64)       36864     ['yolo_v8_head_3_class_2_pad[0
#  v (Conv2D)                                                         ][0]']
#
#  yolo_v8_head_1_box_2_conv   (None, None, None, 64)       36864     ['yolo_v8_head_1_box_2_pad[0][
#  (Conv2D)                                                           0]']
#
#  yolo_v8_head_1_class_2_bn   (None, None, None, 64)       256       ['yolo_v8_head_1_class_2_conv[
#  (BatchNormalization)                                               0][0]']
#
#  yolo_v8_head_2_box_2_conv   (None, None, None, 64)       36864     ['yolo_v8_head_2_box_2_pad[0][
#  (Conv2D)                                                           0]']
#
#  yolo_v8_head_2_class_2_bn   (None, None, None, 64)       256       ['yolo_v8_head_2_class_2_conv[
#  (BatchNormalization)                                               0][0]']
#
#  yolo_v8_head_3_box_2_conv   (None, None, None, 64)       36864     ['yolo_v8_head_3_box_2_pad[0][
#  (Conv2D)                                                           0]']
#
#  yolo_v8_head_3_class_2_bn   (None, None, None, 64)       256       ['yolo_v8_head_3_class_2_conv[
#  (BatchNormalization)                                               0][0]']
#
#  yolo_v8_head_1_box_2_bn (B  (None, None, None, 64)       256       ['yolo_v8_head_1_box_2_conv[0]
#  atchNormalization)                                                 [0]']
#
#  yolo_v8_head_1_class_2 (Ac  (None, None, None, 64)       0         ['yolo_v8_head_1_class_2_bn[0]
#  tivation)                                                          [0]']
#
#  yolo_v8_head_2_box_2_bn (B  (None, None, None, 64)       256       ['yolo_v8_head_2_box_2_conv[0]
#  atchNormalization)                                                 [0]']
#
#  yolo_v8_head_2_class_2 (Ac  (None, None, None, 64)       0         ['yolo_v8_head_2_class_2_bn[0]
#  tivation)                                                          [0]']
#
#  yolo_v8_head_3_box_2_bn (B  (None, None, None, 64)       256       ['yolo_v8_head_3_box_2_conv[0]
#  atchNormalization)                                                 [0]']
#
#  yolo_v8_head_3_class_2 (Ac  (None, None, None, 64)       0         ['yolo_v8_head_3_class_2_bn[0]
#  tivation)                                                          [0]']
#
#  yolo_v8_head_1_box_2 (Acti  (None, None, None, 64)       0         ['yolo_v8_head_1_box_2_bn[0][0
#  vation)                                                            ]']
#
#  yolo_v8_head_1_class_3_con  (None, None, None, 3)        195       ['yolo_v8_head_1_class_2[0][0]
#  v (Conv2D)                                                         ']
#
#  yolo_v8_head_2_box_2 (Acti  (None, None, None, 64)       0         ['yolo_v8_head_2_box_2_bn[0][0
#  vation)                                                            ]']
#
#  yolo_v8_head_2_class_3_con  (None, None, None, 3)        195       ['yolo_v8_head_2_class_2[0][0]
#  v (Conv2D)                                                         ']
#
#  yolo_v8_head_3_box_2 (Acti  (None, None, None, 64)       0         ['yolo_v8_head_3_box_2_bn[0][0
#  vation)                                                            ]']
#
#  yolo_v8_head_3_class_3_con  (None, None, None, 3)        195       ['yolo_v8_head_3_class_2[0][0]
#  v (Conv2D)                                                         ']
#
#  yolo_v8_head_1_box_3_conv   (None, None, None, 64)       4160      ['yolo_v8_head_1_box_2[0][0]']
#  (Conv2D)
#
#  yolo_v8_head_1_classifier   (None, None, None, 3)        0         ['yolo_v8_head_1_class_3_conv[
#  (Activation)                                                       0][0]']
#
#  yolo_v8_head_2_box_3_conv   (None, None, None, 64)       4160      ['yolo_v8_head_2_box_2[0][0]']
#  (Conv2D)
#
#  yolo_v8_head_2_classifier   (None, None, None, 3)        0         ['yolo_v8_head_2_class_3_conv[
#  (Activation)                                                       0][0]']
#
#  yolo_v8_head_3_box_3_conv   (None, None, None, 64)       4160      ['yolo_v8_head_3_box_2[0][0]']
#  (Conv2D)
#
#  yolo_v8_head_3_classifier   (None, None, None, 3)        0         ['yolo_v8_head_3_class_3_conv[
#  (Activation)                                                       0][0]']
#
#  tf.concat_217 (TFOpLambda)  (None, None, None, 67)       0         ['yolo_v8_head_1_box_3_conv[0]
#                                                                     [0]',
#                                                                      'yolo_v8_head_1_classifier[0]
#                                                                     [0]']
#
#  tf.concat_218 (TFOpLambda)  (None, None, None, 67)       0         ['yolo_v8_head_2_box_3_conv[0]
#                                                                     [0]',
#                                                                      'yolo_v8_head_2_classifier[0]
#                                                                     [0]']
#
#  tf.concat_219 (TFOpLambda)  (None, None, None, 67)       0         ['yolo_v8_head_3_box_3_conv[0]
#                                                                     [0]',
#                                                                      'yolo_v8_head_3_classifier[0]
#                                                                     [0]']
#
#  yolo_v8_head_1_output_resh  (None, None, 67)             0         ['tf.concat_217[0][0]']
#  ape (Reshape)
#
#  yolo_v8_head_2_output_resh  (None, None, 67)             0         ['tf.concat_218[0][0]']
#  ape (Reshape)
#
#  yolo_v8_head_3_output_resh  (None, None, 67)             0         ['tf.concat_219[0][0]']
#  ape (Reshape)
#
#  tf.concat_220 (TFOpLambda)  (None, None, 67)             0         ['yolo_v8_head_1_output_reshap
#                                                                     e[0][0]',
#                                                                      'yolo_v8_head_2_output_reshap
#                                                                     e[0][0]',
#                                                                      'yolo_v8_head_3_output_reshap
#                                                                     e[0][0]']
#
#  box_outputs (Activation)    (None, None, 67)             0         ['tf.concat_220[0][0]']
#
#  tf.__operators__.getitem_2  (None, None, 64)             0         ['box_outputs[0][0]']
#  4 (SlicingOpLambda)
#
#  tf.__operators__.getitem_2  (None, None, 3)              0         ['box_outputs[0][0]']
#  5 (SlicingOpLambda)
#
#  box (Concatenate)           (None, None, 64)             0         ['tf.__operators__.getitem_24[
#                                                                     0][0]']
#
#  class (Concatenate)         (None, None, 3)              0         ['tf.__operators__.getitem_25[
#                                                                     0][0]']
#
#  non_max_suppression_11 (No  multiple                     0         []
#  nMaxSuppression)
#
#  yolov8_label_encoder_11 (Y  multiple                     0         []
#  OLOV8LabelEncoder)
#
# ==================================================================================================
# Total params: 3432953 (13.10 MB)
# Trainable params: 3421785 (13.05 MB)
# Non-trainable params: 11168 (43.62 KB)
# __________________________________________________________________________________________________
# None

# %%
import matplotlib.pyplot as plt


model.compile(optimizer=AdamW(learning_rate=0.0001, weight_decay=0.004, global_clipnorm=GLOBAL_CLIPNORM),
                  classification_loss='binary_crossentropy', box_loss='ciou')

def visualize_predict_detections(model, dataset, bounding_box_format, num_images=10, show=True, save_filename=None):
    images, y_true = next(iter(dataset.take(num_images)))

    y_pred = model.predict(images)
    y_pred = keras_cv.bounding_box.to_ragged(y_pred)

    keras_cv.visualization.plot_bounding_box_gallery(
        images,
        value_range=(0, 255),
        bounding_box_format=bounding_box_format,
        y_true=y_true,
        y_pred=y_pred,
        true_color=(192, 57, 43),
        pred_color=(255, 235, 59),
        scale=8,
        font_scale=0.8,
        line_thickness=2,
        dpi=100,
        rows=2,
        cols=2,
        show=show,
        class_mapping=mapping,
    )

    if save_filename:
        plt.savefig(save_filename)
    if show:
        plt.show()

# Example usage
visualize_predict_detections(model, dataset=testing_dataset, bounding_box_format="xyxy", num_images=4, show=False, save_filename="/content/drive/MyDrive/Brain-Tumor-Detection/reports/figures/detections.png")
# Out:
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f3573322830> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 2s 2s/step
